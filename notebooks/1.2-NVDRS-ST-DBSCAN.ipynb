# %% [markdown]
# if you want to use your ZCTA Rank logic, you simply replace the haversine_distances call inside the for loop with a lookup to your zcta_rank_map.

# %%
import sys
import os
sys.path.append(os.path.abspath('..')) # Go up one level to the project root and add it to the path
from src.utils.config import PROJECT_ROOT
from src.geospatial.st_dbscan import run_small_st_dbscan
from src.utils.viz import visualize_st_dbscan_clusters


pop_file = PROJECT_ROOT / "data" / "processed" / "satscan" / "NYC_nores" / "NYC_nores.pop"
cases_file = PROJECT_ROOT / "data" / "processed" / "satscan" / "NYC_nores" / "NYC_nores.cas"
geo_file = PROJECT_ROOT / "data" / "processed" / "satscan" / "NYC_nores" / "NYC_nores.geo"
nyc_clusters = run_small_st_dbscan(
    cas_file=cases_file, 
    geo_file=geo_file, 
    pop_file=pop_file,  # Use Rates
    eps1_km=100.0,      # Huge spatial window
    eps2_days=5000,     # Huge time window
    min_threshold=0.01  # Smaller than 0.05
)
#nyc_clusters=run_small_st_dbscan(cases_file, geo_file, pop_file, eps1_km=1, eps2_days=1, min_threshold=1)
#visualize_st_dbscan_clusters(nyc_clusters, output_dir=PROJECT_ROOT / "outputs", nickname="NYC_rates")
# Out:
# Constructing matrices and executing dense ST-DBSCAN on 3830 records...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/suicide_forecast/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 12
#      10 cases_file = PROJECT_ROOT / "data" / "processed" / "satscan" / "NYC_nores" / "NYC_nores.cas"
#      11 geo_file = PROJECT_ROOT / "data" / "processed" / "satscan" / "NYC_nores" / "NYC_nores.geo"
# ---> 12 nyc_clusters = run_small_st_dbscan(
#      13     cas_file=cases_file,
#      14     geo_file=geo_file,
#      15     pop_file=pop_file,  # Use Rates
#      16     eps1_km=100.0,      # Huge spatial window
#      17     eps2_days=5000,     # Huge time window
#      18     min_threshold=0.01  # Smaller than 0.05
#      19 )
#      20 #nyc_clusters=run_small_st_dbscan(cases_file, geo_file, pop_file, eps1_km=1, eps2_days=1, min_threshold=1)
#      21 #visualize_st_dbscan_clusters(nyc_clusters, output_dir=PROJECT_ROOT / "outputs", nickname="NYC_rates")
#
# File ~/Library/CloudStorage/Box-Box/Matteo Perini/6_SuicideProj/CODE/suicide_forecasting/src/geospatial/st_dbscan.py:85, in run_small_st_dbscan(cas_file, geo_file, pop_file, eps1_km, eps2_days, min_threshold)
#      83 MULTIPLIER = 1000000
#      84 safe_min_samples = int(min_threshold * MULTIPLIER)
# ---> 85 safe_weights = (df['weight'] * MULTIPLIER).astype(int).values
#      87 # 6. Execute Clustering
#      88 db = DBSCAN(eps=eps1_km, min_samples=safe_min_samples, metric='precomputed')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/suicide_forecast/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/suicide_forecast/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'weight'
