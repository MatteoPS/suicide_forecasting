# %% [markdown]
# # Suicide Forecasting — Data Overview
#
# This notebook loads and inspects the NVDRS dataset (`../data/raw/head_keyes_973_nvdrs_2023.csv`) to prepare for downstream analysis and modeling.

# %%
import pandas as pd
file_path = "../data/raw/head_keyes_973_nvdrs_2023.csv"
df = pd.read_csv(file_path, encoding='latin1', low_memory=False)

# %%
print("\n--- Dataset Dimensions (Rows, Columns) ---")
print(df.shape)
# Out:
# --- Dataset Dimensions (Rows, Columns) ---
# (249, 634)

# %%
print("\n--- Summary Statistics ---")
print(df.describe(include='all'))
# Out:
# --- Summary Statistics ---
#         IncidentID  IncidentYear      SiteID  IncidentNumber  \
# count   249.000000         249.0         249      249.000000
# unique         NaN           NaN           6             NaN
# top            NaN           NaN  New Jersey             NaN
# freq           NaN           NaN          65             NaN
# mean    123.734940        2003.0         NaN      740.638554
# std      70.693583           0.0         NaN      473.064194
# min       1.000000        2003.0         NaN       13.000000
# 25%      63.000000        2003.0         NaN      453.000000
# 50%     124.000000        2003.0         NaN      702.000000
# 75%     185.000000        2003.0         NaN      856.000000
# max     245.000000        2003.0         NaN     1899.000000
#
#                                              NarrativeCME  \
# count                                                 239
# unique                                                235
# ...

# %%
print("\n--- First 5 Rows ---")
print(df.head())
# Out:
# --- First 5 Rows ---
#    IncidentID  IncidentYear      SiteID  IncidentNumber  \
# 0           1          2003    Maryland             653
# 1           2          2003  New Jersey             245
# 2           3          2003    Virginia             588
# 3           4          2003    Virginia             591
# 4           5          2003    Virginia             594
#
#                                         NarrativeCME  \
# 0  V was visiting friends when S(s) kicked in the...
# 1  V a 25 year old, single white male found by hi...
# 2  V was found hanging in a closet by her sister....
# 3  V telephoned his boss and told him that he wou...
# 4  P1 was found hanged, half sitting in his close...
#
#                                          NarrativeLE IncidentCategory_c  \
# 0  V was found lying on the ground having sustain...    Single homicide
# 1                                                NaN     Single suicide
# ...
